# %%
from muselsl import *
import numpy as np
import matplotlib.pyplot as plt
from pylsl import StreamInlet, resolve_byprop
import json
import warnings

import xml.dom.minidom

# %%
# -*- coding: utf-8 -*-
"""
Estimate Relaxation from Band Powers
This example shows how to buffer, epoch, and transform EEG data from a single
electrode into values for each of the classic frequencies (e.g. alpha, beta, theta)
Furthermore, it shows how ratios of the band powers can be used to estimate
mental state for neurofeedback.
The neurofeedback protocols described here are inspired by
*Neurofeedback: A Comprehensive Review on System Design, Methodology and Clinical Applications* by Marzbani et. al
Adapted from https://github.com/NeuroTechX/bci-workshop
"""

import numpy as np  # Module that simplifies computations on matrices
import matplotlib.pyplot as plt  # Module used for plotting
from pylsl import StreamInlet, resolve_byprop  # Module to receive EEG data
import utils  # Our own utility functions
from process_data import ChannelDataProcessor, Metrics


# Handy little enum to make code more readable


class Band:
    Delta = 0
    Theta = 1
    Alpha = 2
    Beta = 3


# We are working with 4 channels (Billy) [0], [1], [2], [3] as 4 index_channel values
NUM_CHANNELS = 5

# Length of the EEG data buffer (in seconds)
# This buffer will hold last n seconds of data and be used for calculations
BUFFER_LENGTH = 5

# Length of the epochs used to compute the FFT (in seconds)
EPOCH_LENGTH = 1

# Amount of overlap between two consecutive epochs (in seconds)
OVERLAP_LENGTH = 0.8

# Amount to 'shift' the start of each next consecutive epoch
SHIFT_LENGTH = EPOCH_LENGTH - OVERLAP_LENGTH


def _acquire_eeg_data(_inlet):
    """ Pull EEG data from inlet and return. 

    :return: tuple: _eeg_data, _timestamp
    """
    _eeg_data, _timestamp = _inlet.pull_chunk(
        timeout=1, max_samples=int(SHIFT_LENGTH * fs))
    return _eeg_data, _timestamp

def _acquire_eeg_data_mock():
    """ Get eeg_data and timestamp from json for testing purposes. 

    :return: tuple: _eeg_data, _timestamp
    """
    json_file = open("to_send.json")
    k = json.loads(json_file.read())
    _eeg_data = k[0]["eeg_data"]
    _timestamp = k[0]["timestamp"]
    return _eeg_data, _timestamp

if __name__ == "__main__":

    # """ 1. CONNECT TO EEG STREAM """
    # 
    # Search for active LSL streams
    print('Looking for an EEG stream...')
    streams = resolve_byprop('type', 'EEG', timeout=2)
    if len(streams) == 0:
        raise RuntimeError('Can\'t find EEG stream.')
    
    # Set active EEG stream to inlet and apply time correction
    print("Start acquiring data")
    inlet = StreamInlet(streams[0], max_chunklen=12)
    eeg_time_correction = inlet.time_correction()
    
    # Get the stream info and description
    info = inlet.info()
    description = info.desc()
    
#     dom = xml.dom.minidom.parseString(description.value())
#     print(info.channel_count)
#     print(description.value())
#     print(dom.toprettyxml())
# # description.value
    
    # # Get the sampling frequency
    # # This is an important value that represents how many EEG data points are
    # # collected in a second. This influences our frequency band calculation.
    # # for the Muse 2016, this should always be 256
    
    def get_fs(_info):
        return int(_info.nominal_srate())
    
    def get_fs_mock():
        warnings.warn("Using mock fs value: 256. Make sure that you are using get_fs outside of testing. ")
        return 256  # For testing purposes
    
    fs = get_fs(info)
#     fs = get_fs_mock() 

    """ 3. GET DATA """

    # The try/except structure allows to quit the while loop by aborting the
    # script with <Ctrl-C>
    print('Press Ctrl-C in the console to break the while loop.')
    deltas = []
    thetas = []
    alphas = []
    betas = []
    try:
        # The following loop acquires data, computes band powers, and calculates neurofeedback metrics based on those band powers
        while True:
            #
            """ 3.1 ACQUIRE DATA """
            
            # Obtain EEG data from the LSL stream
            eeg_data, timestamp = _acquire_eeg_data(inlet) 
#             eeg_data, timestamp = _acquire_eeg_data_mock()
            
            c = ChannelDataProcessor(buffer_length=BUFFER_LENGTH, 
                                     epoch_length=EPOCH_LENGTH, 
                                     overlap_length=OVERLAP_LENGTH, 
                                     shift_length=SHIFT_LENGTH, fs=fs, band_cls=Band)
            
            c.feed_new_data(eeg_data=eeg_data)          # Feed new data generated in the epoch
            metrics = np.zeros(NUM_CHANNELS)                       
            delta_sample = []
            theta_sample = []
            alpha_sample = []
            beta_sample = []
            for i in range(NUM_CHANNELS):               # Iterate through all separate channels

                
                # Record channel smooth band power
                csbp = c.get_channel_smooth_band_powers(i)
                delta_sample.append(csbp[0])
                theta_sample.append(csbp[1])
                alpha_sample.append(csbp[2])
                beta_sample.append(csbp[3])
                
                # Run calculations on csbp to obtain desired metrics
                beta_metric = Metrics.beta_protocol(csbp, Band)
                #print("Alpha metric: {}".format(alpha_metric))
                
                metrics[i] = beta_metric

            #print("alpha metric for 4 sensors are separately: {}".format(metrics))
            print(" ")
            deltas.append(delta_sample)
            thetas.append(theta_sample)
            alphas.append(alpha_sample)
            betas.append(beta_sample)
            
    except KeyboardInterrupt:
        print('Closing!')
# Out:
# Looking for an EEG stream...
# Start acquiring data
# Press Ctrl-C in the console to break the while loop.
# Beta Concentration:  -0.8198875062685185
# Beta Concentration:  0.40239030343812604
# Beta Concentration:  0.3533434665369567
# Beta Concentration:  -0.803726814270128
# Beta Concentration:  2.8630071509960184
#
# Beta Concentration:  -1.1577084016729502
# Beta Concentration:  3.0349351507056266
# Beta Concentration:  6.746269040862719
# Beta Concentration:  -0.6685282437627267
# Beta Concentration:  0.7595000428768672
#
# Beta Concentration:  -0.11976901997060375
# Beta Concentration:  0.8097883925745597
# Beta Concentration:  0.729865886403896
# Beta Concentration:  -0.009366099574849043
# Beta Concentration:  2.81577569811154
#
# Beta Concentration:  -4.721807246668743
# Beta Concentration:  0.6339267356765746
# Beta Concentration:  0.49640558221274267
# Beta Concentration:  -4.140878359142744
# Beta Concentration:  8.179887354135165
#
# Beta Concentration:  1.725567660813634
# Beta Concentration:  0.5825272859656794
# Beta Concentration:  0.4932394181549318
# Beta Concentration:  1.5372801537162857
# Beta Concentration:  1.493410211513503
#
# Beta Concentration:  4.7902824684166045
# Beta Concentration:  1.184690959386535
# Beta Concentration:  0.6773118457517918
# Beta Concentration:  2.735602671569143
# Beta Concentration:  -29.769073192216382
#
# Beta Concentration:  3.7673163305684514
# Beta Concentration:  2.2806588139698896
# Beta Concentration:  1.8007675703130308
# Beta Concentration:  3.9392810015824407
# Beta Concentration:  0.9767257837693243
#
# Beta Concentration:  1.9204327761574052
# Beta Concentration:  1.2250748404473637
# Beta Concentration:  0.8460778349483555
# Beta Concentration:  1.3493017190758483
# Beta Concentration:  1.0555291818655108
#
# Beta Concentration:  9.058918445015776
# Beta Concentration:  0.9481195082311146
# Beta Concentration:  0.3347071774819152
# Beta Concentration:  4.84164849395587
# Beta Concentration:  0.9222814924846378
#
# Beta Concentration:  2.630197059369161
# Beta Concentration:  1.1527853988656962
# Beta Concentration:  0.6582304215472133
# Beta Concentration:  4.316089028481743
# Beta Concentration:  0.5883469299202363
#
# Beta Concentration:  7.87283834116447
# Beta Concentration:  4.050879917279636
# Beta Concentration:  6.222935594412242
# Beta Concentration:  3.831172591802309
# Beta Concentration:  -0.8456207458745427
#
# Beta Concentration:  -1.3237678794680405
# Beta Concentration:  0.5379270153030048
# Beta Concentration:  0.38573362581050125
# Beta Concentration:  -1.9085099193537047
# Beta Concentration:  0.8141381005429269
#
# Beta Concentration:  -2.3419938285879645
# Beta Concentration:  0.5018415594126474
# Beta Concentration:  0.462760915396852
# Beta Concentration:  -3.182714257971555
# Beta Concentration:  0.17068089080005563
#
# Beta Concentration:  -3.275311746050242
# Beta Concentration:  0.8221253412229944
# Beta Concentration:  -3.0521476740110853
# Beta Concentration:  -4.005095826253212
# Beta Concentration:  5.070514145700501
#
# Beta Concentration:  2.6813296107178015
# Beta Concentration:  1.4605081427988353
# Beta Concentration:  0.6279349694444831
# Beta Concentration:  5.740790314917405
# Beta Concentration:  4.544038820628947
#
# Beta Concentration:  19.261553090945032
# Beta Concentration:  -2.939554572068822
# Beta Concentration:  0.7458544083776595
# Beta Concentration:  6.396845327943867
# Beta Concentration:  0.8244904768106536
#
# Beta Concentration:  4.1110694083747585
# Beta Concentration:  -12.136833024312041
# Beta Concentration:  8.781198950433327
# Beta Concentration:  3.5950777001883734
# Beta Concentration:  1.1906871064536417
#
# Beta Concentration:  0.007075001667075212
# Beta Concentration:  0.5588080907636935
# Beta Concentration:  0.5797950156237648
# Beta Concentration:  0.03139241755947422
# Beta Concentration:  0.6325626125984565
#
# Beta Concentration:  -0.6492479196822675
# Beta Concentration:  5.007223436315414
# Beta Concentration:  2.26835142386022
# Beta Concentration:  -0.7150815440419872
# Beta Concentration:  2.604022446138638
#
# Beta Concentration:  2.2564730744956574
# Beta Concentration:  0.7345555403896432
# Beta Concentration:  1.058314958687758
# Beta Concentration:  3.1973126235638802
# Beta Concentration:  2.2207930415939217
#
# Beta Concentration:  58.09979569967198
# Beta Concentration:  16.150921097220905
# Beta Concentration:  0.8943708905001214
# Beta Concentration:  5.761097887074455
# Beta Concentration:  0.45636339927043956
#
# Beta Concentration:  8.160789044252533
# Beta Concentration:  -4.58315679755057
# Beta Concentration:  -1.3959008051495863
# Beta Concentration:  81.68339307039784
# Beta Concentration:  54801.523472142326
#
# Beta Concentration:  -41.34561018877912
# Beta Concentration:  0.7538797315595057
# Beta Concentration:  0.6712012627126261
# Beta Concentration:  9.787550474212813
# Beta Concentration:  2.195897910355883
#
# Beta Concentration:  0.23041788227797688
# Beta Concentration:  0.3779151521249692
# Beta Concentration:  0.27770721819389005
# Beta Concentration:  0.14734609291476244
# Beta Concentration:  1.0554579272660185
#
# Beta Concentration:  22.57812556382935
# Beta Concentration:  142.789571883565
# Beta Concentration:  1.0724942283422658
# Beta Concentration:  4.2729227678389226
# Beta Concentration:  2.0847069390630684
#
# Beta Concentration:  -1.0555934624231265
# Beta Concentration:  0.49631735615772027
# Beta Concentration:  0.3860105021306364
# Beta Concentration:  -1.1360009439453207
# Beta Concentration:  1.4409090785965004
#
# Beta Concentration:  -0.2540211188008156
# Beta Concentration:  0.5688318838671929
# Beta Concentration:  0.6385476895021831
# Beta Concentration:  -0.3142844037794363
# Beta Concentration:  1.791991629208289
#
# Beta Concentration:  -0.08601386952223117
# Beta Concentration:  0.6012278522665266
# Beta Concentration:  0.5534444554065207
# Beta Concentration:  -0.09802942222408742
# Beta Concentration:  28.534704561124897
#
# Beta Concentration:  -10.416998383769918
# Beta Concentration:  4.7255555638842175
# Beta Concentration:  0.6304744618720889
# Beta Concentration:  -4.91763074196391
# Beta Concentration:  0.8537194322062396
#
# Beta Concentration:  3.312056496364198
# Beta Concentration:  0.6437361220580775
# Beta Concentration:  0.5563412414472346
# Beta Concentration:  2.4823544721546744
# Beta Concentration:  1.0460796545850848
#
# Beta Concentration:  -0.947941796935642
# Beta Concentration:  0.7121306073890921
# Beta Concentration:  1.009247300344064
# Beta Concentration:  -1.1987360460905279
# Beta Concentration:  6.8901699661088305
#
# Beta Concentration:  -0.7764234782097758
# Beta Concentration:  0.7300480929685718
# Beta Concentration:  0.9542707304838499
# Beta Concentration:  -0.6966839662720721
# Beta Concentration:  1.362139244868174
#
# Beta Concentration:  -2.6623131352740677
# Beta Concentration:  0.8422789770218579
# Beta Concentration:  0.9365247691496383
# Beta Concentration:  -6.73753792622396
# Beta Concentration:  1.5168455717106606
#
# Beta Concentration:  3.357502556382635
# Beta Concentration:  -10.045909583942127
# Beta Concentration:  3.752245318142998
# Beta Concentration:  6.109153081134874
# Beta Concentration:  1.067101282344304
#
# Beta Concentration:  16.53331547344003
# Beta Concentration:  1.5652177220961099
# Beta Concentration:  0.6212114986446851
# Beta Concentration:  6.940309786310941
# Beta Concentration:  -3.640703141262377
#
# Beta Concentration:  0.18822852253934785
# Beta Concentration:  0.3966521176005226
# Beta Concentration:  0.3954376072909351
# Beta Concentration:  0.19975114245885242
# Beta Concentration:  1.1507237155180325
#
# Beta Concentration:  -0.9218958767141412
# Beta Concentration:  1.9607096205163725
# Beta Concentration:  5.4549154888509435
# Beta Concentration:  -0.6292295970919739
# Beta Concentration:  5.300384479856866
#
# Beta Concentration:  9.462947878992741
# Beta Concentration:  -2.251466125925222
# Beta Concentration:  1.0860173031110785
# Beta Concentration:  8.686892401951184
# Beta Concentration:  6.555082002542182
#
# Beta Concentration:  -1.3595674468634475
# Beta Concentration:  0.36199242464435805
# Beta Concentration:  0.3063046881505589
# Beta Concentration:  -1.3114091276702367
# Beta Concentration:  0.7499341080210915
#
# Beta Concentration:  -1.45265906948204
# Beta Concentration:  0.5311770193893133
# Beta Concentration:  0.4325241165445345
# Beta Concentration:  -1.9488438449244034
# Beta Concentration:  0.8432000924034396
#
# Beta Concentration:  -1.0489917792731571
# Beta Concentration:  0.6640102300060665
# Beta Concentration:  0.6785699337200429
# Beta Concentration:  -1.6968234785556822
# Beta Concentration:  0.9688793407914064
# Beta Concentration:  3.8446850168322038
# Beta Concentration:  2.2649098729371575
# Beta Concentration:  0.7471654415243864
# Beta Concentration:  2.582803166707071
# Beta Concentration:  1.7256742289773543
#
# Beta Concentration:  -2.0244526789359036
# Beta Concentration:  0.6780984271718432
# Beta Concentration:  0.41990314338898166
# Beta Concentration:  -2.5637955110870236
# Beta Concentration:  0.9617454327985485
#
# Beta Concentration:  0.20164193252470528
# Beta Concentration:  0.5498175955840776
# Beta Concentration:  0.5556550759855401
# Beta Concentration:  0.16448210218844894
# Beta Concentration:  0.43443047649214295
#
# Beta Concentration:  -0.7324681740969476
# Beta Concentration:  1.137138786395201
# Beta Concentration:  0.38177847798438874
# Beta Concentration:  -0.675229649443261
# Beta Concentration:  3.3932891990784513
#
# Beta Concentration:  -0.101572893663242
# Beta Concentration:  0.39855764129707066
# Beta Concentration:  0.4115612944260834
# Beta Concentration:  -0.09291674439910733
# Beta Concentration:  2.183850729242481
#
# Beta Concentration:  -0.4170327266899026
# Beta Concentration:  0.4679468819981114
# Beta Concentration:  0.3800906611862726
# Beta Concentration:  -0.6529976018749214
# Beta Concentration:  1.5190854710408428
#
# Beta Concentration:  -0.9278480819363173
# Beta Concentration:  0.5995420232094606
# Beta Concentration:  0.43782885301566343
# Beta Concentration:  -1.0740885512175162
# Beta Concentration:  -3.6612001480388843
#
# Beta Concentration:  -1.0676600107610088
# Beta Concentration:  0.4800860488374186
# Beta Concentration:  0.4552069010015603
# Beta Concentration:  -0.7499272034572663
# Beta Concentration:  0.8344463456237408
#
# Beta Concentration:  0.9601602742005017
# Beta Concentration:  0.5684111634738911
# Beta Concentration:  0.5426674695628615
# Beta Concentration:  3.677548448151652
# Beta Concentration:  1.0625726643804996
#
# Beta Concentration:  5.326522676846388
# Beta Concentration:  0.8792878457156914
# Beta Concentration:  0.8576301328923194
# Beta Concentration:  6.304092083176022
# Beta Concentration:  1.7482505169842353
#
# Beta Concentration:  3.6204663224982605
# Beta Concentration:  0.7054269057929268
# Beta Concentration:  0.723663491597423
# Beta Concentration:  6.232541744486949
# Beta Concentration:  0.3403113518663281
#
# Beta Concentration:  5.6575825156152195
# Beta Concentration:  1.0853756067201228
# Beta Concentration:  0.5045651677854934
# Beta Concentration:  3.1492119082316896
# Beta Concentration:  1.373956074451641
#
# Beta Concentration:  1.785599644312995
# Beta Concentration:  -1.663261823015517
# Beta Concentration:  3.9385858902911037
# Beta Concentration:  1.613903562692675
# Beta Concentration:  1.3147970302262821
#
# Beta Concentration:  2.1356702440813726
# Beta Concentration:  -1.8235879090765583
# Beta Concentration:  1.282591847041372
# Beta Concentration:  2.819886623026701
# Beta Concentration:  1.2760035440111273
#
# Beta Concentration:  -1.8120175553525328
# Beta Concentration:  0.44964594742750563
# Beta Concentration:  0.27017323672444676
# Beta Concentration:  -2.191896554346519
# Beta Concentration:  4.726649602957783
#
# Closing!

# %%
thetas
# Out:
# [[0.027080094013804474,
#   0.04307969962285625,
#   0.04525204138904593,
#   0.02820186549381042,
#   -0.004988279819932072],
#  [0.01289965989733113,
#   0.0064893059633092534,
#   0.002730737590208447,
#   0.01620731016278457,
#   -0.01993625672423425],
#  [0.020874480186016904,
#   0.03633918693416842,
#   0.035144418062164035,
#   0.022795347193007645,
#   -0.0036355519059021687],
#  [0.0046785261641279895,
#   0.035137990301026364,
#   0.039626674214974296,
#   0.0052167566297191235,
#   -0.001790045130212442],
#  [-0.017099748633392108,
#   0.040769724249240476,
#   0.03792197236263317,
#   -0.02239763931707026,
#   -0.008966750689521633],
